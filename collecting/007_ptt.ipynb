# %% [markdown]
# ### Ptt 論壇爬蟲(適用各個主題版)
# ### Ptt Crawler

# %%
from bs4 import BeautifulSoup
from typing import Tuple
import requests
import re

# comment's ip of some boards was hidden.
hide_comment_ip_board = [
    'Stock',
    'Sex'
]


class PttCrawler:
    """Fetch post information on PTT.

    Guide
    1. Initialize the board you need.
    2. Get the number of maximum page.
    3. Generate urls of each page.
    4. Take API of the post in one page.
    """

    def __init__(self, board_name):
        """Initialize.

        Initialize with board homepage,
        We need cookie for passing.
        """
        self.board_name = board_name
        self.url = f'https://www.ptt.cc/bbs/{board_name}/index.html'

        session = requests.Session()
        session.get(self.url)
        ck = session.cookies.get_dict()
        ck['over18'] = '1'
        ck = ';'.join([k + '=' + v for k, v in ck.items()])

        # go homepage of the board first for header para.
        header = {
            'cookie': ck,
        }
        self.header = header

    def get_total_page(self) -> int:
        """Get the total number of pages of this board."""
        res = requests.get(self.url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')
        last_page_url = soup.findAll('a', text='‹ 上頁')[0]['href']
        total_page = int(re.findall(r'/index(\w+)', last_page_url)[0])
        self.total_page = total_page

        return total_page

    def get_urls_of_posts(self, page_no: int) -> list:
        """Generate post's url of selected page."""
        if page_no > self.total_page:
            raise ValueError('page_no is more than the max it had.')

        url = f'https://www.ptt.cc/bbs/{self.board_name}/index{page_no}.html'
        res = requests.get(url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')
        post_urls = [
            a['href'].split('/')[-1]
            for a in soup.find_all(
                'a', text=re.compile('\[+')
            )
        ]
        return post_urls

    def get_api_of_whole_page(self, page_no: int) -> dict:
        """Go through whole page with get api of each post."""
        output = {}
        urls = self.get_urls_of_posts(page_no)
        for i in len(range(urls)):
            url = f'https:// www.ptt.cc/bbs/{self.board_name}/{urls[i]}'
            output[i] = self.get_api_of_post(url)
        return output

    def get_api_of_post(self, post_url: str) -> dict:
        """Take all element on a page."""
        soup = self.get_soup_of_post(post_url)
        content = self.get_post_content(soup)
        author, board, title, post_time = self.get_post_info(soup)
        comment = self.get_post_comment(soup)

        return {
            'url': post_url,
            'board': author,
            'author': board,
            'title': title,
            'post_time': post_time,
            'content': content,
            'comment': comment,
        }

    def get_soup_of_post(self, post_url) -> BeautifulSoup:
        """Get source of a post."""
        url = f'https://www.ptt.cc/bbs/{self.board_name}/{post_url}'
        res = requests.get(url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')

        return soup

    def get_post_content(self, post_soup: BeautifulSoup) -> str:
        """Description of process.

        Strings of contents are contained in 'main-content' without tagging.
        We should retrive content by its tag not belong to div and span.
        (Type of content belong to 'NavigableString')
        """
        output = ""
        for c in post_soup.find_all(
            'div', {'id': 'main-content'}
        )[0].contents:

            if (c.name not in ['div', 'span']) \
                    and (c.string is not None):
                output += c.string

        return output.strip()

    def get_post_info(
        self, post_soup: BeautifulSoup
    ) -> Tuple[str, str, str, str]:
        """Get basic information of a post."""
        author, board, title, post_time = post_soup.find_all(
            'span', {'class': 'article-meta-value'}
        )

        return (
            author.getText(), board.getText(),
            title.getText(), post_time.getText()
        )

    def get_post_comment(self, post_soup: BeautifulSoup) -> dict:
        """Get comments of a post."""
        comment_ele = post_soup.find_all('div', {'class': 'push'})
        comments = {}
        if len(comment_ele) > 0:
            for idx, div in enumerate(comment_ele):

                push_tag, user, comment, info = div.find_all('span')

                # some board with no ip address for comments,
                # e.g. Stock, Sex..
                if self.board_name in hide_comment_ip_board:
                    comment_date, comment_time = info.getText().split()
                    ip = None
                else:
                    ip, comment_date, comment_time = info.getText().split()

                comments[idx] = {
                    'push_tag': push_tag.getText().strip(),
                    'user': user.getText().strip(),
                    'comment': comment.getText().strip(),
                    'ip': ip,
                    'comment_date': comment_date.strip(),
                    'comment_time': comment_time.strip(),
                }
            return comments
        else:
            return comments

# %%
board = PttCrawler('Gossiping')
total_pages = board.get_total_page()
print(total_pages)
# Out:
# 39779

# %%
urls_of_one_page = board.get_urls_of_posts(total_pages)
print(urls_of_one_page)
# Out:
# ['M.1622810270.A.4BE.html', 'M.1622810303.A.CC6.html', 'M.1622810329.A.779.html', 'M.1622810342.A.989.html', 'M.1622810346.A.BCF.html', 'M.1622810390.A.1D4.html', 'M.1622810429.A.AF2.html', 'M.1622810442.A.636.html', 'M.1622810443.A.9DD.html', 'M.1622810446.A.1DB.html', 'M.1622810495.A.176.html', 'M.1622810521.A.113.html', 'M.1622810530.A.0CC.html', 'M.1622810540.A.0F4.html', 'M.1622810550.A.549.html', 'M.1622810551.A.785.html', 'M.1622810588.A.769.html', 'M.1622810655.A.993.html', 'M.1622810656.A.CEB.html']

# %%
board.get_api_of_post(urls_of_one_page[0])
# Out:
# {'url': 'M.1622810270.A.4BE.html',
#  'board': 'Elipton (壞人變態色鬼)',
#  'author': 'Gossiping',
#  'title': 'Re: [問卦] 我有資格開幹了吧！',
#  'post_time': 'Fri Jun  4 20:37:48 2021',
#  'content': '1，3，4在死亡案例的簡介都看得到\n\n今天有個發病日只是發燒\n\n3天就掰了的3X歲男子\n\n5的話\n\n只能說正常吧\n\n一個剛畢業的醫學生可能會為自己的無力痛哭\n\n久了以後\n\n他除了把資源盡可能地公平分配\n\n你還要他怎樣呢？\n\n陪你一起多愁善感嗎？\n\n--',
#  'comment': {0: {'push_tag': '→',
#    'user': 'kiddingsa',
#    'comment': ': 冤有頭債有主 弒母之仇 別留到下輩子',
#    'ip': '223.137.28.81',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   1: {'push_tag': '推',
#    'user': 'sulichun',
#    'comment': ': 你是那位醫師嗎？我覺得你也蠻冷血的',
#    'ip': '36.230.68.247',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   2: {'push_tag': '推',
#    'user': 'anous',
#    'comment': ': 就每個人都以為自己最重要，怎麼可以不關',
#    'ip': '114.136.97.188',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   3: {'push_tag': '→',
#    'user': 'anous',
#    'comment': ': 心我，前幾天砍護理師的那個廢物還不是這',
#    'ip': '114.136.97.188',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   4: {'push_tag': '→',
#    'user': 'anous',
#    'comment': ': 樣',
#    'ip': '114.136.97.188',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   5: {'push_tag': '→',
#    'user': 'anxcvi',
#    'comment': ': 弒母的是病毒 不是誰',
#    'ip': '111.240.174.22',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   6: {'push_tag': '噓',
#    'user': 'niukb',
#    'comment': ': IP正確 cccc 你是不是在...認...知...',
#    'ip': '125.224.95.34',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   7: {'push_tag': '→',
#    'user': 'kiddingsa',
#    'comment': ': 我能確定的 只有不是醫護 至於是誰 問',
#    'ip': '223.137.28.81',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   8: {'push_tag': '→',
#    'user': 'kiddingsa',
#    'comment': ': 問自己的良心吧',
#    'ip': '223.137.28.81',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   9: {'push_tag': '推',
#    'user': 'horse2819',
#    'comment': ': 真的不用遷怒醫師',
#    'ip': '111.83.165.25',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   10: {'push_tag': '噓',
#    'user': 'ffboy',
#    'comment': ': 你只想到你自己',
#    'ip': '223.139.101.222',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   11: {'push_tag': '推',
#    'user': 'kkiiccooo',
#    'comment': ': 推 你講的很理性 雖然是ip是中國',
#    'ip': '114.47.123.54',
#    'comment_date': '06/04',
#    'comment_time': '20:44'},
#   12: {'push_tag': '推',
#    'user': 'Anyotw',
#    'comment': ': 就沒有藥醫啊。只能幫你葉克膜…停電就沒',
#    'ip': '39.12.6.164',
#    'comment_date': '06/04',
#    'comment_time': '20:44'},
#   13: {'push_tag': '→',
#    'user': 'Anyotw',
#    'comment': ': 了',
#    'ip': '39.12.6.164',
#    'comment_date': '06/04',
#    'comment_time': '20:44'}}}

# %%
board.get_api_of_post(urls_of_one_page[1])
# Out:
# {'url': 'M.1622810303.A.CC6.html',
#  'board': 'derekhsu (華麗的天下無雙)',
#  'author': 'Gossiping',
#  'title': '[爆卦] 疫情整理:英國確診狂飆 馬國回歸校正爆量',
#  'post_time': 'Fri Jun  4 20:38:15 2021',
#  'content': '- 馬來西亞病例持續回歸校正，6/2日的新增死亡病例數竟比原先增加60%，達到單日128\n例，馬來西亞目前的疫情有被大幅低估可能。\n\n- 哥倫比亞新增確診與死亡病例數均創歷史新高。\n\n- 印度昨天新增確診病例數創下近期新低。\n\n\n\n- 繼昨天新增確診病例數暴增之後，今天墨西哥死亡病例數也暴增，可能是有於回歸校正\n的關係，因此墨西哥疫情也有被低估可能。\n\n- 阿富汗疫情持續惡化，新增確診病例數創歷史新高。\n\n- 非洲南部多國疫情進入緊急狀態。\n\n\n\n- 德國慕尼黑大學(Munich University)科學家的一項重大新研究發現，封鎖對降低該國\n的冠狀病毒感染率沒有效果。\n([https://t.co/JQQDhzvOmw?amp=1](https://t.co/JQQDhzvOmw?amp=1))\n\n- 根據YouGov的調查，大多數美國人認爲冠狀病毒大流行起源於武漢病毒學研究所，近四\n分之一的美國人認爲這是故意發佈的。\n([https://t.co/tXnFT6ZVSu?amp=1](https://t.co/tXnFT6ZVSu?amp=1))\n\n- 最新消息:英國將批准輝瑞爲12歲至15歲人群接種的冠狀病毒疫苗\n\n- \n([https://t.co/NUZtAuxlHT?amp=1](https://t.co/NUZtAuxlHT?amp=1))（湯姆克魯斯：\n氣氣氣氣氣氣氣）\n\n\n\n([https://t.co/Q82dQSoZLz?amp=1](https://t.co/Q82dQSoZLz?amp=1))\n\n- 有症狀病例上升了80%，西北部和蘇格蘭受影響最嚴重\n([https://t.co/B82ao6nuHB?amp=1](https://t.co/B82ao6nuHB?amp=1))\n\n- 新的數據表明，在英國，使用輝瑞疫苗的人針對Delta變種的抗體程度低於針對其他變\n體的抗體程度。研究還表明，隨着年齡的增長，這些抗體的程度會降低，隨着時間的推移\n，水平會降低。研究人員說，這提供了額外的證據，支持在秋季爲脆弱人羣提供疫苗接種\n的計劃。([\n([https://t.co/qWDu5UmVMm?amp=1](https://t.co/qWDu5UmVMm?amp=1))(他們比\n較的對象是，也就是我們現在面對的這種)\n\n0. 全球\n\n474,634確診(-15%) 10,736死亡(-10%) 563,814復原\n\n1. 印度\n\n131,371確診(-32%)  205,911復原\n\n2. 巴西\n\n83,391確診(4%) 2,078死亡(5%) 60,653復原\n\n3. 阿根廷\n\n32,291確診(2%) 553死亡(9%) 29,121復原\n\n4. 哥倫比亞\n\n 23,440復原\n\n5. 美國\n\n17,821確診(-33%) 574死亡(-8%) 39,064復原\n\n6. 伊朗\n\n9,657確診(-3%) 170死亡(-8%) 14,799復原\n\n7. 俄羅斯\n\n8,933確診(6%) 393死亡(1%) 9,383復原\n\n8. 馬來西亞\n\n8,209確診(11%) 103死亡(54%) 7,049復原\n\n- 馬來西亞再度回歸校正，6/2死亡病例數暴增至128例，為歷史新高，原本為71例，暴增\n超過60%。\n\n9. 法國\n\n8,161確診(-13%) 71死亡(-22%) 6,469復原\n\n10. 智利\n\n8,128確診(13%) 213死亡(23%) 6,043復原\n\n16. 英國\n\n 18死亡(-5%) 2,267復原\n\n- 英國疫情進入指數增加期，昨天新增確診病例數比前天增加將近1000例。\n- 英國死亡病例數隨確診病例數進入回升期。\n\n23. 墨西哥\n\n3,269確診(39%)  849復原\n\n墨西哥死亡病例數隨昨天新增確診病例數暴增，可能是回歸校正所造成。\n\n39. 阿富汗\n\n) 107復原\n\n49. 烏干達\n\n 1死亡(-64%)復原\n\n57. 尚比亞\n\n 死亡(30%)12復原\n\n58. 葡萄牙\n\n 3死亡(13%)88復原\n\n葡萄牙連續2天新增確診病例數創近期新高。\n\n60. 納米比亞\n\n 12死亡(46%) 129復原\n\n特別報導\n\n72. 台灣\n\n408確診(-17%) 17死亡(歷史第三, 143%) 0復原\n\n- 台灣昨天累積確診病例數超過1萬例，是世界上第157個國，排在南蘇丹之後。\n- 台灣昨天新增確診病例數介於肯亞與摩洛哥之間。\n- 台灣昨天累積死亡病例數達到166例，超過巴布紐新幾內亞、幾內亞、吉布地、剛果、\n加彭共和國，只比台灣前邦交國布吉那法索少一例。\n- 台灣昨天新增死亡病例與肯亞和波札那並列世界第50名。\n- 台灣週增死亡病例率為143%，成為全球週增死亡病例超過10例的國家當中排行世界第一\n。\n\n86. 越南\n\n250確診(16%) 0死亡(-57%) 0復原\n\n--\n要持續觀察，死亡病例落後2週，2週後回來看不遲，台灣就是一個範例。',
#  'comment': {0: {'push_tag': '推',
#    'user': 'heyd',
#    'comment': ': 外國也玩回歸校正？',
#    'ip': '111.83.188.246',
#    'comment_date': '06/04',
#    'comment_time': '20:38'},
#   1: {'push_tag': '→',
#    'user': 'WolfTeacher',
#    'comment': ': 台灣異軍突起',
#    'ip': '180.176.0.145',
#    'comment_date': '06/04',
#    'comment_time': '20:39'},
#   2: {'push_tag': '→',
#    'user': 'sockrover',
#    'comment': ': 台灣領先世界 是世界要跟上台灣',
#    'ip': '61.230.52.123',
#    'comment_date': '06/04',
#    'comment_time': '20:39'},
#   3: {'push_tag': '→',
#    'user': 'Anvec',
#    'comment': ': 目前就是 mRNA 疫苗對新變種病毒效果較佳',
#    'ip': '124.155.174.232',
#    'comment_date': '06/04',
#    'comment_time': '20:39'},
#   4: {'push_tag': '→',
#    'user': 'tpck',
#    'comment': ': 英國的AZ還是不太行吧 死亡病例又跑出來了',
#    'ip': '1.171.104.217',
#    'comment_date': '06/04',
#    'comment_time': '20:39'},
#   5: {'push_tag': '推',
#    'user': 'zxcfluter',
#    'comment': ': 校正回歸領先全球',
#    'ip': '218.173.45.61',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   6: {'push_tag': '推',
#    'user': 'goiohi',
#    'comment': ': AZ+BNT混打初步研究好像很強',
#    'ip': '114.40.209.195',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   7: {'push_tag': '推',
#    'user': 'popy8789',
#    'comment': ': 看吧 有不止台灣矯正回歸',
#    'ip': '223.137.36.153',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   8: {'push_tag': '→',
#    'user': 'tpck',
#    'comment': ': 英國不就混打',
#    'ip': '1.171.104.217',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   9: {'push_tag': '推',
#    'user': 'ups',
#    'comment': ': 推',
#    'ip': '59.124.228.83',
#    'comment_date': '06/04',
#    'comment_time': '20:40'},
#   10: {'push_tag': '→',
#    'user': 'castjane',
#    'comment': ': 根本沒差 az 重症有效啊',
#    'ip': '220.137.111.205',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   11: {'push_tag': '→',
#    'user': 'goiohi',
#    'comment': ': 目前沒有大規模混打的國家吧 都是研究性質',
#    'ip': '114.40.209.195',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   12: {'push_tag': '→',
#    'user': 'tpck',
#    'comment': ': 台灣還是要多買一些mRNA疫苗比較保險',
#    'ip': '1.171.104.217',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   13: {'push_tag': '推',
#    'user': 'countryair',
#    'comment': ': 英國是不是又開始佛系了',
#    'ip': '42.73.55.248',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   14: {'push_tag': '推',
#    'user': 'Lindseyy',
#    'comment': ': 所以az到底行不行',
#    'ip': '123.193.47.100',
#    'comment_date': '06/04',
#    'comment_time': '20:41'},
#   15: {'push_tag': '→',
#    'user': 'popy8789',
#    'comment': ': 英國不是都打AZ嗎',
#    'ip': '223.137.36.153',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   16: {'push_tag': '→',
#    'user': 'countryair',
#    'comment': ': AZ韓國的研究看起來還不錯呀',
#    'ip': '42.73.55.248',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   17: {'push_tag': '推',
#    'user': 'Mazda6',
#    'comment': ': AZ就是60-90%  台灣只剩高端能打',
#    'ip': '1.169.169.34',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   18: {'push_tag': '推',
#    'user': 'taihsin',
#    'comment': ': 打AZ 讓你得了比較不會重症',
#    'ip': '1.200.171.25',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   19: {'push_tag': '→',
#    'user': 'popy8789',
#    'comment': ': AZ跟高端比 當然行',
#    'ip': '223.137.36.153',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   20: {'push_tag': '推',
#    'user': 'sding',
#    'comment': ': 感謝整理',
#    'ip': '118.150.193.228',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   21: {'push_tag': '推',
#    'user': 'hnhnhn',
#    'comment': ': 18例死亡 防重症效果還是有的',
#    'ip': '1.172.2.133',
#    'comment_date': '06/04',
#    'comment_time': '20:42'},
#   22: {'push_tag': '→',
#    'user': 'tpck',
#    'comment': ': 不會重症那英國怎麼還有死亡病例',
#    'ip': '1.171.104.217',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   23: {'push_tag': '推',
#    'user': 'ME13',
#    'comment': ': 怕',
#    'ip': '101.137.149.134',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   24: {'push_tag': '推',
#    'user': 'ted01234567',
#    'comment': ': Taiwan no.72',
#    'ip': '36.230.175.220',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   25: {'push_tag': '→',
#    'user': 'jimmykuo123',
#    'comment': ': 台灣NO1 讓世界看見台灣',
#    'ip': '1.169.69.131',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   26: {'push_tag': '→',
#    'user': 'countryair',
#    'comment': ': 重症的或死亡的接種比例沒呈現',
#    'ip': '42.73.55.248',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   27: {'push_tag': '推',
#    'user': 'ardoctor',
#    'comment': ': 英國都打哪一支疫苗啊?',
#    'ip': '210.242.225.103',
#    'comment_date': '06/04',
#    'comment_time': '20:43'},
#   28: {'push_tag': '→',
#    'user': 'david190',
#    'comment': ': 英國是BNT跟Az都有打',
#    'ip': '114.39.218.253',
#    'comment_date': '06/04',
#    'comment_time': '20:44'},
#   29: {'push_tag': '推',
#    'user': 'guest8888',
#    'comment': ': 世界看好了',
#    'ip': '180.217.43.212',
#    'comment_date': '06/04',
#    'comment_time': '20:44'},
#   30: {'push_tag': '推',
#    'user': 'zakijudelo',
#    'comment': ': 印度變種又在英國等國肆虐了',
#    'ip': '101.12.64.233',
#    'comment_date': '06/04',
#    'comment_time': '20:45'},
#   31: {'push_tag': '→',
#    'user': 'tpck',
#    'comment': ': 台灣要積極一點買mRNA疫苗啦',
#    'ip': '1.171.104.217',
#    'comment_date': '06/04',
#    'comment_time': '20:45'},
#   32: {'push_tag': '→',
#    'user': 'zakijudelo',
#    'comment': ': https://i.imgur.com/G3WjShi.jpg',
#    'ip': '101.12.64.233',
#    'comment_date': '06/04',
#    'comment_time': '20:46'},
#   33: {'push_tag': '推',
#    'user': 'numlocka',
#    'comment': ': 推',
#    'ip': '36.234.158.143',
#    'comment_date': '06/04',
#    'comment_time': '20:46'},
#   34: {'push_tag': '推',
#    'user': 'coffee112',
#    'comment': ': 不是有疫苗了嗎？ @@怕',
#    'ip': '101.9.241.58',
#    'comment_date': '06/04',
#    'comment_time': '20:46'},
#   35: {'push_tag': '推',
#    'user': 'JuiFu617',
#    'comment': ': 確診沒差啊，不要重症就好了',
#    'ip': '39.8.130.82',
#    'comment_date': '06/04',
#    'comment_time': '20:46'},
#   36: {'push_tag': '→',
#    'user': 'Katarn',
#    'comment': ': 英國被印度變種逆襲 所以疫情再起...',
#    'ip': '122.116.224.15',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   37: {'push_tag': '推',
#    'user': 'sandking',
#    'comment': ': 周增死亡世界第一，感恩綠共',
#    'ip': '219.70.106.19',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   38: {'push_tag': '推',
#    'user': 'hwider',
#    'comment': ': 謝謝整理',
#    'ip': '223.138.120.110',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   39: {'push_tag': '→',
#    'user': 'minoru04',
#    'comment': ': 英國之前不是靠狂打疫苗壓住了嗎',
#    'ip': '114.40.83.136',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   40: {'push_tag': '推',
#    'user': 'rusa',
#    'comment': ': 完蛋 還要防印度那株',
#    'ip': '122.116.239.198',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   41: {'push_tag': '推',
#    'user': 'euruing',
#    'comment': ': 有無重症的數據蠻重要的',
#    'ip': '42.77.96.52',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   42: {'push_tag': '→',
#    'user': 'reiborei',
#    'comment': ': 慘了 之前說英國打AZ才安全下莊的怎麼辦',
#    'ip': '36.229.31.217',
#    'comment_date': '06/04',
#    'comment_time': '20:47'},
#   43: {'push_tag': '→',
#    'user': 'potionx',
#    'comment': ': 印度變種再變種的KAPPA不知道強不強',
#    'ip': '111.243.108.128',
#    'comment_date': '06/04',
#    'comment_time': '20:48'},
#   44: {'push_tag': '→',
#    'user': 'CYL009',
#    'comment': ': 3+11沒改遲早會讓印度株進來的',
#    'ip': '1.200.30.8',
#    'comment_date': '06/04',
#    'comment_time': '20:48'}}}
