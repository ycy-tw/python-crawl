# %% [markdown]
# ### 臺灣上市公司融資融券(包含ETF)
# ### Taiwan listed firm's margin purhcase and short sales information(including ETF)

# %%
from pandas.core.frame import DataFrame
import requests
import pandas as pd


def get_margin(date: str) -> DataFrame:

    url = 'https://www.twse.com.tw/exchangeReport/'
    url += f'MI_MARGN?response=json&date={date}&selectType=ALL'

    res = requests.get(url)
    source = res.json()
    df = pd.DataFrame(source['data'], columns=source['fields'])

    return df

# %%
get_margin('20210720')
# Out:
#       股票代號     股票名稱   買進   賣出 現金償還    前日餘額    今日餘額       限額  買進 賣出 現券償還 前日餘額  \
# 0     0050   元大台灣50   41   35    0     476     482  329,250   0  0    0    0
# 1     0051  元大中型100   10    0    0      26      36    2,625   0  0    0    0
# 2     0052     富邦科技   22    7    0     162     177   13,875   0  0    0    0
# 3     0053     元大電子    0    0    0       1       1    1,372   0  0    0    0
# 4     0054   元大台商50    0    0    0       0       0    1,781   0  0    0    0
# ...    ...      ...  ...  ...  ...     ...     ...      ...  .. ..  ...  ...
# 1066  9944       新麗   14  130    0   6,462   6,346   27,276   1  0    0   20
# 1067  9945      潤泰新  441  899    0  10,430   9,972  376,220  30  0    5   35
# 1068  9946     三發地產    0   10    0     976     966   77,750   0  0    0    0
# 1069  9955       佳龍   11    6    0     930     935   25,802   0  1    0   10
# 1070  9958      世紀鋼  260  492    0  12,831  12,599   57,735   8  8    0  443
#
#      今日餘額       限額 資券互抵  註記
# 0       0  329,250    0
# 1       0    2,625    0
# 2       0   13,875    0
# 3       0    1,372    0
# 4       0    1,781    0  X
# ...   ...      ...  ...  ..
# 1066   19   27,276    0
# 1067    0  376,220    0  X
# 1068    0   77,750    0
# 1069   11   25,802    0
# 1070  443   57,735    0
#
# [1071 rows x 16 columns]
