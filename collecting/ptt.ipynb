# %% [markdown]
# ### Ptt 論壇爬蟲(適用各個主題版)
# ### Ptt Crawler

# %%
from bs4 import BeautifulSoup
from typing import Tuple
import requests
import re
import pandas as pd

# comment's ip of some boards was hidden.
hide_comment_ip_board = [
    'Stock',
    'Sex'
]


class PttCrawler:
    """Fetch post information on PTT.

    Guide
    1. Initialize the board you need.
    2. Get the number of maximum page.
    3. Generate urls of each page.
    4. Take API of the post in one page.
    """

    def __init__(self, board_name):
        """Initialize.

        Initialize with board homepage,
        We need cookie for passing.
        """
        self.board_name = board_name
        self.url = f'https://www.ptt.cc/bbs/{board_name}/index.html'

        session = requests.Session()
        session.get(self.url)
        ck = session.cookies.get_dict()
        ck['over18'] = '1'
        ck = ';'.join([k + '=' + v for k, v in ck.items()])

        # go homepage of the board first for header para.
        header = {
            'cookie': ck,
        }
        self.header = header

    def get_total_page(self) -> int:
        """
        Get the total number of pages of this board.
        """

        res = requests.get(self.url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')
        last_page_url = soup.findAll('a', text='‹ 上頁')[0]['href']
        total_page = int(re.findall(r'/index(\w+)', last_page_url)[0])
        self.total_page = total_page

        return total_page

    def get_urls_of_posts(self, page_no: int) -> list:
        """
        Generate post's url of selected page.
        """

        if page_no > self.total_page:
            raise ValueError('page_no is more than the max it had.')

        url = f'https://www.ptt.cc/bbs/{self.board_name}/index{page_no}.html'
        res = requests.get(url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')
        post_urls = [
            a['href'].split('/')[-1]
            for a in soup.find_all(
                'a', text=re.compile('\[+')
            )
        ]
        return post_urls

    def get_api_of_whole_page(self, page_no: int) -> dict:
        """
        Go through whole page with get api of each post.
        """

        output = {}
        urls = self.get_urls_of_posts(page_no)
        for i in len(range(urls)):
            url = f'https:// www.ptt.cc/bbs/{self.board_name}/{urls[i]}'
            output[i] = self.get_api_of_post(url)
        return output

    def get_api_of_post(self, post_url: str) -> dict:
        """
        Take all element on a page.
        """

        soup = self.get_soup_of_post(post_url)
        content = self.get_post_content(soup)
        board, author, title, post_time = self.get_post_info(soup)
        comment = self.get_post_comment(soup)

        return {
            'url': post_url,
            'board': author,
            'author': board,
            'title': title,
            'post_time': post_time,
            'content': content,
            'comment': comment,
        }

    def get_soup_of_post(self, post_url) -> BeautifulSoup:
        """
        Get source of a post.
        """

        url = f'https://www.ptt.cc/bbs/{self.board_name}/{post_url}'
        res = requests.get(url, headers=self.header)
        soup = BeautifulSoup(res.text, 'html.parser')

        return soup

    def get_post_content(self, post_soup: BeautifulSoup) -> str:
        """Description of process.

        Strings of contents are contained in 'main-content' without tagging.
        We should retrieve content by its tag not belong to div and span.
        (Type of content belong to 'NavigableString')
        """

        output = ""
        for c in post_soup.find_all(
            'div', {'id': 'main-content'}
        )[0].contents:

            if (c.name not in ['div', 'span']) \
                    and (c.string is not None):
                output += c.string

        return output.strip()

    def get_post_info(
        self, post_soup: BeautifulSoup
    ) -> Tuple[str, str, str, str]:

        """Get basic information of a post."""

        author, board, title, post_time = post_soup.find_all(
            'span', {'class': 'article-meta-value'}
        )

        return (
            author.getText(), board.getText(),
            title.getText(), post_time.getText()
        )

    def get_post_comment(self, post_soup: BeautifulSoup) -> dict:
        """
        Get comments of a post.
        """

        comment_ele = post_soup.find_all('div', {'class': 'push'})
        comments = {}
        if len(comment_ele) > 0:
            for idx, div in enumerate(comment_ele):

                push_tag, user, comment, info = div.find_all('span')

                # some board with no ip address for comments,
                # e.g. Stock, Sex..
                if self.board_name in hide_comment_ip_board:
                    comment_date, comment_time = info.getText().split()
                    ip = None
                else:
                    ip, comment_date, comment_time = info.getText().split()
                
                comments[idx] = {
                    'push_tag': push_tag.getText().strip(),
                    'user': user.getText().strip(),
                    'comment': comment.getText().strip()[1:],
                    'ip': ip,
                    'comment_date': comment_date.strip(),
                    'comment_time': comment_time.strip(),
                }
            return comments
        else:
            return comments

# %%
# set 'Stock' as target board
board = PttCrawler('Stock')

# get total page of the board
total_pages = board.get_total_page()
print(total_pages)
# Out:
# 5164

# %%
# demo1
# get url in one of the target board's page
urls_of_one_page = board.get_urls_of_posts(total_pages)

# take the information of one post
# ['url', 'board', 'author', 'title', 'post_time', 'content', 'comment']
data = board.get_api_of_post(urls_of_one_page[0])
data
# Out:
# {'url': 'M.1654966541.A.93B.html',
#  'board': 'Stock',
#  'author': 'DrowningPool (My broken dreams)',
#  'title': '[新聞] 台股擂台 郭哲榮本周押寶晶華鳳凰',
#  'post_time': 'Sun Jun 12 00:55:37 2022',
#  'content': '原文標題：台股擂台/挑戰者「華爾街大亨」郭哲榮 本周押寶晶華、鳳凰\n\n原文連結：https://money.udn.com/money/story/5607/6381406\n\n發布時間：2022-6-12\n\n記者署名：張瀞文\n\n原文內容：\n\n上周戰報\n在上周，「華爾街大亨」。\n\n他上周持有的五檔個股中，以六福（2705）漲5.2%最優，主要是百張以上大戶籌碼集中，\n後市持續看好。但鳳凰漲多拉回，前一周大漲一成多，上周回吐3.3%，高檔整理，表現最\n弱，但也沒大跌。\n\n本周布局\n在新的一周，郭哲榮的現金比重維持在零，持有個股數目也維持在五檔不變，每檔都各配\n置20%的比重。其中，，全都是受惠於解封的觀光產業，郭哲榮持續看\n好解封後的受惠股。\n\n在新的投資組合中，郭哲榮最看好續抱股。隨著全球疫苗覆蓋率提升，邊境逐漸解封\n，加上政府國旅補助措施即將上路，晶華旗下擁有國際觀光旅館及餐飲等事業，業績將逐\n漸回溫，後市看好。\n\n還有三檔續抱股，看好和投資的理由都不變。將受惠下半年有望開放出境旅遊題材激\n勵，還有日本6月10日開放團客入境釋出的商機；同樣可望受惠於國境解封；旗\n下聚集飯店、遊樂園、餐飲等事業，有望迎接民眾的報復性出遊潮，且百張以上大戶籌碼\n激增，顯示法人看好後市。\n\n還有一檔新增個股，受惠國旅補助，也是解封概念股。\n\n最佳一檔\n晶華（2707）\n理由：觀光股的績優股\n\n多空診斷室\n本周有許多重要經濟事件，；美國聯準會（Fed）利率決議，預計升息2碼；加上台積電除息，但美\n國10年期公債殖利率再度衝破3%，也讓科技股承受壓力。所以本周台股要挑戰季線，難度\n不低，但只要有任何舒緩通貨膨脹的利多出現，台股就有機會放量突破。\n\n投資錦囊妙計\n近期台股走勢較為震盪，現階段的盤面群龍無首，加上量能低迷，目前選股方向，可留意\n5月營收特別突出的個股，或下半年景氣展望比較明朗的族群，並且採取短打策略，，嚴設停利停損。另外，資金控管上要謹慎為宜，，分批\n進場布局為宜\n\nhttps://i.imgur.com/MD5gjD7.jpg\nhttps://i.imgur.com/Dpt8JDl.jpg\nhttps://i.imgur.com/t44wWUi.jpg\n\n心得/評論：\n\n上周說還好沒選山富的 投資長聽到了喔 \u3000\u3000@[email\xa0protected]\n不過下周台股應該選誰都不重要了吧  呵呵\n\n倒是對折的錦囊妙計怎都跟實際操作相反呢\n見壞就砍？？？\n嚴設停損？？？\n切勿追高？？？\n\n--',
#  'comment': {0: {'push_tag': '推',
#    'user': 'kevin28',
#    'comment': ' 觀光保重',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '00:56'},
#   1: {'push_tag': '推',
#    'user': 'avmm9898',
#    'comment': ' 星期一隨便選一檔股票放空都是賺',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '00:57'},
#   2: {'push_tag': '推',
#    'user': 'dbdudsorj',
#    'comment': ' 觀光股下台一鞠躬',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '00:58'},
#   3: {'push_tag': '推',
#    'user': 'yellone741',
#    'comment': ' 下週誰虧的少就算贏',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:02'},
#   4: {'push_tag': '推',
#    'user': 'davidaustin',
#    'comment': ' 解封股',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:02'},
#   5: {'push_tag': '→',
#    'user': 'swgun',
#    'comment': ' 日幣跌爆壓晶華...',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:02'},
#   6: {'push_tag': '推',
#    'user': 'EddieWuRJJ',
#    'comment': ' 下週全綠 逃不掉的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:03'},
#   7: {'push_tag': '推',
#    'user': 'NEX4036',
#    'comment': ' 鳳凰臺上鳳凰游 鳳去臺空江自流',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:03'},
#   8: {'push_tag': '推',
#    'user': 'torce',
#    'comment': ' 求求投資長放過台股，放過股民',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:03'},
#   9: {'push_tag': '噓',
#    'user': 'JessVeron',
#    'comment': ' 蠻聰明的啊  看美股慘不選電子  賭觀光蠻有邏輯的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:03'},
#   10: {'push_tag': '推',
#    'user': 'icedog122',
#    'comment': ' 丸子',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:04'},
#   11: {'push_tag': '→',
#    'user': 'NEX4036',
#    'comment': ' 遊啦',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:04'},
#   12: {'push_tag': '噓',
#    'user': 'JessVeron',
#    'comment': ' 不然酸民要不推薦哪個族群一下？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:07'},
#   13: {'push_tag': '推',
#    'user': 'vbfg60219g',
#    'comment': ' +~表示 空',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:13'},
#   14: {'push_tag': '噓',
#    'user': 'shevchen',
#    'comment': ' 垃圾分吸濕',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:13'},
#   15: {'push_tag': '推',
#    'user': 'Tenging',
#    'comment': ' 慘',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:21'},
#   16: {'push_tag': '推',
#    'user': 'littleshan30',
#    'comment': ' 藥華藥：好險',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:24'},
#   17: {'push_tag': '噓',
#    'user': 'Tatsuya72',
#    'comment': ' 蹭什麼觀光股',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:30'},
#   18: {'push_tag': '推',
#    'user': 'KadourZiani',
#    'comment': ' 坐等折折押藥藥哈哈',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:36'},
#   19: {'push_tag': '推',
#    'user': 'p8331407',
#    'comment': ' 讚還好我沒有',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '01:42'},
#   20: {'push_tag': '推',
#    'user': 'nashQ',
#    'comment': ' 賭觀光蠻聰明的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:04'},
#   21: {'push_tag': '→',
#    'user': 'monkeyboy041',
#    'comment': ' 所以才這麼久還在500',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:07'},
#   22: {'push_tag': '→',
#    'user': 'cloud701002',
#    'comment': ' 酸民完全沒選股能力，只能跟折折對做',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:34'},
#   23: {'push_tag': '推',
#    'user': 'lepidoptera',
#    'comment': ' 反正不管選什麼 星期一都逃不掉',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:38'},
#   24: {'push_tag': '推',
#    'user': 'etop',
#    'comment': ' 崩崩',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:41'},
#   25: {'push_tag': '推',
#    'user': 'kuso5522',
#    'comment': ' 沒藥華滿意外的，表示高點還沒到。',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '02:49'},
#   26: {'push_tag': '→',
#    'user': 'guilty13',
#    'comment': ' 好屌  每周都可以選  當投顧真的爽~',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:16'},
#   27: {'push_tag': '→',
#    'user': 'diabolica',
#    'comment': ' 懷念了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:24'},
#   28: {'push_tag': '推',
#    'user': 'thg156yu789',
#    'comment': ' 下週大概剩生技可以玩',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:38'},
#   29: {'push_tag': '推',
#    'user': 'Kobe5210',
#    'comment': ' 沒有選股能力的人,才會幫韭菜投顧說話',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:42'},
#   30: {'push_tag': '→',
#    'user': 'Kobe5210',
#    'comment': '   看到這咖玩紙上大富翁,有選股能力的人當然會笑+酸',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:44'},
#   31: {'push_tag': '→',
#    'user': 'Kobe5210',
#    'comment': ' 市場上沒選股能力的懶散戶超多,投顧才能上下其手',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:46'},
#   32: {'push_tag': '推',
#    'user': 'Kobe5210',
#    'comment': ' 會員費收到爽,還有錢請公關網軍貼文貼圖刷流量',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:50'},
#   33: {'push_tag': '→',
#    'user': 'Kobe5210',
#    'comment': ' 一個願打,一個願挨;自己選的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '03:54'},
#   34: {'push_tag': '→',
#    'user': 'Kobe5210',
#    'comment': ' 一樣是小資散戶自己努力,01的Jacky8000都可敬多了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '04:03'},
#   35: {'push_tag': '推',
#    'user': 'CLucci',
#    'comment': ' 原來哲哲其實也還蠻強的，500萬也還剩496萬，王文良',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '06:28'},
#   36: {'push_tag': '→',
#    'user': 'CLucci',
#    'comment': ' 賠到只剩425萬',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '06:28'},
#   37: {'push_tag': '推',
#    'user': 'abuu0929',
#    'comment': ' 經濟日報周末選股，卻用前一個禮拜五收盤價當成成本',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:20'},
#   38: {'push_tag': '→',
#    'user': 'abuu0929',
#    'comment': ' 價，績效根本就是假的，哲哲之前單季超高績效也是這',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:20'},
#   39: {'push_tag': '→',
#    'user': 'abuu0929',
#    'comment': ' 樣做出來的，毫無意義',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:20'},
#   40: {'push_tag': '推',
#    'user': 'Klan',
#    'comment': ' G然沒有藥華',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:25'},
#   41: {'push_tag': '噓',
#    'user': 'xxxkey',
#    'comment': ' 看名先虛',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:29'},
#   42: {'push_tag': '→',
#    'user': 'tinybunny',
#    'comment': ' 至少在股市大富翁下個單給大家看看，盤後才講',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:39'},
#   43: {'push_tag': '推',
#    'user': 'katanakiller',
#    'comment': ' 觀光炒完可以閃了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:39'},
#   44: {'push_tag': '推',
#    'user': 'NEX4036',
#    'comment': ' 其實只是不知道哪時候吵完而已',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:40'},
#   45: {'push_tag': '→',
#    'user': 'NEX4036',
#    'comment': ' 炒完了大概就跟快篩一樣每天盤跌吧',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:40'},
#   46: {'push_tag': '推',
#    'user': 'GoGoRoll',
#    'comment': ' 雖然規則很瞎，但是至少大家同一規則比賽，選這些',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:48'},
#   47: {'push_tag': '→',
#    'user': 'GoGoRoll',
#    'comment': ' 類股還算合邏輯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:48'},
#   48: {'push_tag': '→',
#    'user': 'Coffeewater',
#    'comment': ' 觀光差不多要出貨了 下週應該是生技週',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:59'},
#   49: {'push_tag': '→',
#    'user': 'vanii40',
#    'comment': ' 丸子',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:20'},
#   50: {'push_tag': '→',
#    'user': 'loopdiuretic',
#    'comment': '  https://i.imgur.com/PRA6Lm5.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:25'},
#   51: {'push_tag': '推',
#    'user': 'stocktonty',
#    'comment': ' 還在旅遊股 主力下週倒爛',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:36'},
#   52: {'push_tag': '→',
#    'user': 'aqualan',
#    'comment': ' 淦 這選股的手法真是令人咋舌',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:43'},
#   53: {'push_tag': '噓',
#    'user': 'g987669',
#    'comment': ' 已出，頭汁掌耗孶為汁',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:46'},
#   54: {'push_tag': '推',
#    'user': 'Messi100',
#    'comment': ' 怎沒選生技 藥華藥超強',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:54'},
#   55: {'push_tag': '推',
#    'user': 'YoCheng',
#    'comment': ' 太神啦折折',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:11'},
#   56: {'push_tag': '推',
#    'user': 'empirica',
#    'comment': ' 可能沒注意到藥華藥',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:13'},
#   57: {'push_tag': '推',
#    'user': 'loveponpon',
#    'comment': ' 樂華樂上次被哲哲喊到後 股價回跌20%',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:14'},
#   58: {'push_tag': '推',
#    'user': 'wisebani',
#    'comment': ' 一開放旅遊，就利多出盡大跌的機會不小. 飛東京來回',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:18'},
#   59: {'push_tag': '→',
#    'user': 'wisebani',
#    'comment': ' 機票現在2萬多，只剩下有錢人去的起',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:18'},
#   60: {'push_tag': '推',
#    'user': 'ntuooo',
#    'comment': ' 丸子',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:37'},
#   61: {'push_tag': '→',
#    'user': 'laechan',
#    'comment': ' 旅行社概念股還沒死,不過只能做短，10%就跑吧',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:11'},
#   62: {'push_tag': '→',
#    'user': 'laechan',
#    'comment': ' 放寬入境管制剛好碰到暑假,再貴都有人會想去',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:12'},
#   63: {'push_tag': '推',
#    'user': 'yayaya9487',
#    'comment': ' 會有一堆人搶著去啦 三年出國一次幾萬哪會捨不得花',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:15'},
#   64: {'push_tag': '推',
#    'user': 'weekend88123',
#    'comment': ' 虛擬大富翁之王',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:18'},
#   65: {'push_tag': '推',
#    'user': 'alfi2016',
#    'comment': ' 鳳凰一鳴 股價躺平',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:20'},
#   66: {'push_tag': '噓',
#    'user': 'baseken',
#    'comment': ' GG 可憐哪',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:23'},
#   67: {'push_tag': '噓',
#    'user': 'leon771170',
#    'comment': ' 股后精華被蹭到變晶華',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:24'},
#   68: {'push_tag': '推',
#    'user': 'loveup',
#    'comment': ' 沒生技給差評',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:39'},
#   69: {'push_tag': '→',
#    'user': 'yolasiku',
#    'comment': ' 丸惹',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:59'},
#   70: {'push_tag': '推',
#    'user': 'u8702116',
#    'comment': ' 太早',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:20'},
#   71: {'push_tag': '推',
#    'user': 'afterrmg',
#    'comment': ' 鳳凰要變烤雞了嗎',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:54'},
#   72: {'push_tag': '推',
#    'user': 'Wenerrix',
#    'comment': ' 榮耀華西街',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:07'},
#   73: {'push_tag': '→',
#    'user': 'kilhi',
#    'comment': ' 虛擬遊戲',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:16'},
#   74: {'push_tag': '推',
#    'user': 'ynd',
#    'comment': ' 透抽長99999999999999995',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:51'},
#   75: {'push_tag': '→',
#    'user': 'lolic',
#    'comment': ' 大學生虛擬單競賽都比較強',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:07'},
#   76: {'push_tag': '噓',
#    'user': 'KingChang711',
#    'comment': ' 觀光股拜拜',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:12'},
#   77: {'push_tag': '→',
#    'user': 'tamama000',
#    'comment': ' 觀光又要被臭翻了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:14'},
#   78: {'push_tag': '推',
#    'user': 'jenchieh5',
#    'comment': ' 全面狙擊準備數錢',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:15'},
#   79: {'push_tag': '推',
#    'user': 'badguy227',
#    'comment': ' 還在觀光，連雞排都快吃不起了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:22'},
#   80: {'push_tag': '推',
#    'user': 'k75131',
#    'comment': ' 透支掌太強惹，188d拉風蘭仁',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:33'},
#   81: {'push_tag': '推',
#    'user': 'yjk',
#    'comment': ' 辣個南人，你敢嘴他？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:55'},
#   82: {'push_tag': '推',
#    'user': 'FIFI8488',
#    'comment': ' 油都漲翻天了 還在觀光',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '15:35'},
#   83: {'push_tag': '推',
#    'user': 'Boxun0404',
#    'comment': ' 謝謝投資長放過金項鍊',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:14'},
#   84: {'push_tag': '推',
#    'user': 'billionaire',
#    'comment': ' https://i.imgur.com/hqZqP77.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '19:53'},
#   85: {'push_tag': '噓',
#    'user': 'jkjkallen',
#    'comment': ' 這也可以炒',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '22:32'},
#   86: {'push_tag': '噓',
#    'user': 'sa87a16',
#    'comment': ' 馬B 點名我觀光股幹嘛',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '23:13'},
#   87: {'push_tag': '→',
#    'user': 'sa87a16',
#    'comment': ' 一個月賺10%秘密基地給你搞爛',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '23:14'}}}

# %%
df = pd.DataFrame(data['comment']).T
df
# Out:
#    push_tag         user                           comment    ip comment_date  \
# 0         推      kevin28                              觀光保重  None        06/12
# 1         推     avmm9898                   星期一隨便選一檔股票放空都是賺  None        06/12
# 2         推    dbdudsorj                          觀光股下台一鞠躬  None        06/12
# 3         推   yellone741                         下週誰虧的少就算贏  None        06/12
# 4         推  davidaustin                               解封股  None        06/12
# ..      ...          ...                               ...   ...          ...
# 83        推    Boxun0404                        謝謝投資長放過金項鍊  None        06/12
# 84        推  billionaire   https://i.imgur.com/hqZqP77.jpg  None        06/12
# 85        噓    jkjkallen                             這也可以炒  None        06/12
# 86        噓      sa87a16                       馬B 點名我觀光股幹嘛  None        06/12
# 87        →      sa87a16                   一個月賺10%秘密基地給你搞爛  None        06/12
#
#    comment_time
# 0         00:56
# 1         00:57
# 2         00:58
# 3         01:02
# 4         01:02
# ..          ...
# 83        17:14
# 84        19:53
# 85        22:32
# 86        23:13
# 87        23:14
#
# [88 rows x 6 columns]

# %%
# demo2
urls_of_one_page = board.get_urls_of_posts(total_pages)
data = board.get_api_of_post(urls_of_one_page[1])
data
# Out:
# {'url': 'M.1654991667.A.8F8.html',
#  'board': 'Stock',
#  'author': 'Coffeewater (淡淡的咖啡)',
#  'title': '[新聞] 美國物價大漲 拜登怪罪普丁通膨',
#  'post_time': 'Sun Jun 12 07:54:25 2022',
#  'content': '-------------------------------發文提醒----------------------------------\n1.發文前請先詳閱[新聞]分類發文規範，未依規範發文將受處份。\n2.連結過長請善用 https://bit.ly/ 等縮網址服務，連結不能點擊者板規1-2-2處份。\n3.心得/評論請盡量充實，心得過短或濫竽充數將以板規 1-2-3、4-4 水桶處份。\n4.發文請依照格式文章標明段落，不符合格式者依4-1刪文處分。\n------------------------ 按ctrl+y以上內容。 ----------------------\n\n原文標題：\n\n美國物價大漲 拜登怪罪普丁通膨\n\n原文連結：\n\nhttps://www.chinatimes.com/newspapers/20220612000495-260301?chdtv\n\n發布時間：\n\n2022/6/12\n\n記者署名：\n\n王少筠\n\n原文內容：\n\n美國5月消費者物價指數（CPI）年增8.6％，創40年來最大漲幅。全美普通無鉛汽油平均\n價格也在11日來到每加侖5.004美元，堪比2008年金融海嘯時的油價。拜登總統10日發表\n聲明，將物價上漲怪罪於「普丁通膨」（Putin’s Price Hike），表示「我們持續捍衛\n烏克蘭自由的同時，也必須迅速採取更多行動，來降低美國的物價。」\n\n\n美國勞工部統計局10日公布的數據重賞拜登一巴掌，因為一天前，白宮官員才透露5月CPI\n報告有望出現通膨趨緩、經濟穩定增長等趨勢，不料實際數據卻事與願違，不僅能源價格\n較過去一年飆升34.6％，糧食價格也上漲10.1％，整體CPI更增加整整1％。\n\n拜登表示，「普丁通膨」席捲全球，自俄軍入侵烏克蘭以來，汽油、能源、糧食的價格每\n月都在上漲，他呼籲國會協助減輕通膨造成的財政負擔，並重申政府會「竭盡所能為美國\n人民降低物價」。\n\n能源價格並非拉高通膨的唯一因素，富國證券資深經濟學家豪斯（Sarah House）分析：\n「俄烏戰事複雜化、中國封城防疫、旅行人流激增，再加上一些主要煉油廠關門…各方因\n素加總形成完美風暴，通膨壓力幾乎無處不在。」她大膽預估，就總體通膨而言，「高峰\n還沒到」。\n\n此外，5月扣除通膨後的實質平均時薪、周薪，分別較去年同期減少3％、3.9％，比4月的\n減幅2.6％、3.4％更大；物價升幅遠超過薪資升幅，消費者信心指數（CCI）不斷下降。\n密西根大學10日公布CCI初估值，從5月的58.4降為6月的50.2，是有紀錄以來的新低。\n\n美國期中選舉臨近，加重拜登政府的政經壓力。外界預期聯準會（Fed）將在下周升息2碼\n（0.5個百分點），可能在未來幾個月進行一系列更大幅度升息，但如此一來將使成長倒\n退，華爾街經濟學家和中小企業愈發擔心明年可能出現經濟衰退。\n\n\n心得/評論：\n\n美國總統拜登發表聲明\n通膨席捲全球\n需要採取行動\n自俄軍入侵烏克蘭以來，汽油、能源、糧食的價格每月都在上漲\n並將這個現象稱為普丁通膨\n\n--',
#  'comment': {0: {'push_tag': '推',
#    'user': 'y1896547',
#    'comment': ' 抗俄保美 美國價值 新美國模式',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:55'},
#   1: {'push_tag': '推',
#    'user': 'KyleSeager',
#    'comment': ' 那烏俄戰爭前的通膨是？？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:57'},
#   2: {'push_tag': '→',
#    'user': 'AustinRivers',
#    'comment': ' =.=a',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:57'},
#   3: {'push_tag': '噓',
#    'user': 'a38654',
#    'comment': ' 美國蔡英文 都是阿共的錯！',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '07:59'},
#   4: {'push_tag': '推',
#    'user': 'cpz',
#    'comment': ' 美國jobs讚',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:02'},
#   5: {'push_tag': '推',
#    'user': 'shumann1810',
#    'comment': ' 美版o總統 只會怪別人 記得要多取經XD',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:07'},
#   6: {'push_tag': '→',
#    'user': 'fmp1234',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:10'},
#   7: {'push_tag': '推',
#    'user': 'torce',
#    'comment': ' 121，拜登基，殺爆台股，殺台G',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:10'},
#   8: {'push_tag': '→',
#    'user': 'a79111010',
#    'comment': ' 馬.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:15'},
#   9: {'push_tag': '推',
#    'user': 'adsf1105',
#    'comment': ' 異次元切割',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:16'},
#   10: {'push_tag': '→',
#    'user': 's60621s60621',
#    'comment': ' 拜登：我們會為物價禱告',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:18'},
#   11: {'push_tag': '推',
#    'user': 'elyoje',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:23'},
#   12: {'push_tag': '推',
#    'user': 'billy56',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:24'},
#   13: {'push_tag': '推',
#    'user': 'MinJun5566',
#    'comment': ' 都是they的troll',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:25'},
#   14: {'push_tag': '推',
#    'user': 'gd9381',
#    'comment': ' 米國版EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:31'},
#   15: {'push_tag': '推',
#    'user': 'digodi',
#    'comment': ' 美國蔡EE，理由伯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:41'},
#   16: {'push_tag': '推',
#    'user': 'YumingHuang',
#    'comment': ' 普丁替死鬼 XD',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:41'},
#   17: {'push_tag': '推',
#    'user': 'a0921387223',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:43'},
#   18: {'push_tag': '推',
#    'user': 'rul284dl',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:52'},
#   19: {'push_tag': '推',
#    'user': 'aqoojack0204',
#    'comment': ' 怎麼跟某島國總統有點像...',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:55'},
#   20: {'push_tag': '推',
#    'user': 'YCL13',
#    'comment': ' 真擔心接下來會不會怪台灣晶片賣太貴呀',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:58'},
#   21: {'push_tag': '推',
#    'user': 'ezoboy',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '08:59'},
#   22: {'push_tag': '推',
#    'user': 'topaaron12',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:03'},
#   23: {'push_tag': '推',
#    'user': 'pisu',
#    'comment': ' 難道忘記自己是美國總統？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:03'},
#   24: {'push_tag': '推',
#    'user': 'maxboy06',
#    'comment': ' 西台灣境外勢力害的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:06'},
#   25: {'push_tag': '推',
#    'user': 'stlotwa',
#    'comment': ' 以前都酸馬，現在我改酸EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:07'},
#   26: {'push_tag': '推',
#    'user': 'marcowang',
#    'comment': ' 講完後 也沒有對策 笑死',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:12'},
#   27: {'push_tag': '推',
#    'user': 'towierc',
#    'comment': ' 普丁只是神助攻= =重點是你美國無限QE啊',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:20'},
#   28: {'push_tag': '推',
#    'user': 'wadeguys',
#    'comment': ' 為了捍衛前蘇聯成員國的自由，不顧自己國內人民的',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:20'},
#   29: {'push_tag': '→',
#    'user': 'wadeguys',
#    'comment': ' 生活，好個登',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:20'},
#   30: {'push_tag': '→',
#    'user': 'windalso',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:20'},
#   31: {'push_tag': '推',
#    'user': 'kid1a2b3c4d',
#    'comment': ' 有普丁在根本不會戰爭',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:23'},
#   32: {'push_tag': '推',
#    'user': 'richard520',
#    'comment': ' 所以要不要解決問題，派人去暗殺！？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:23'},
#   33: {'push_tag': '推',
#    'user': 'kid1a2b3c4d',
#    'comment': ' 幹講川普啦 打錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:30'},
#   34: {'push_tag': '→',
#    'user': 'letmesee3085',
#    'comment': ' 美國菜EE?',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:31'},
#   35: {'push_tag': '噓',
#    'user': 'vvnews',
#    'comment': ' 世界怎麼跟得上台灣 自己爛都they的錯XD',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:31'},
#   36: {'push_tag': '噓',
#    'user': 'EDFR',
#    'comment': ' 左膠喜迎通膨  繼續選拜崩  ^^',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:33'},
#   37: {'push_tag': '推',
#    'user': 'ethan0419',
#    'comment': ' 通膨沒救了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:34'},
#   38: {'push_tag': '推',
#    'user': 'zakijudelo',
#    'comment': ' 馬的，小丑就是你自己跟廢物鮑爾，還想推卸責任啊',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:36'},
#   39: {'push_tag': '推',
#    'user': 'pg2000',
#    'comment': ' 去年就一堆人警告了，那個時候是開戰了哦',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:36'},
#   40: {'push_tag': '推',
#    'user': 'chluke',
#    'comment': ' 普維拉',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:39'},
#   41: {'push_tag': '噓',
#    'user': 'steven961302',
#    'comment': ' 屁話仔',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:40'},
#   42: {'push_tag': '推',
#    'user': 'tomdavis',
#    'comment': ' https://i.imgur.com/JykCk8u.jpg 普丁害der',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:40'},
#   43: {'push_tag': '推',
#    'user': 'Danteva',
#    'comment': ' 跟台灣有87趴像',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:41'},
#   44: {'push_tag': '推',
#    'user': 'Jungggg',
#    'comment': ' 世界怎麼跟得上台灣 全部都怪他國政府就好',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:42'},
#   45: {'push_tag': '噓',
#    'user': 'deedo',
#    'comment': ' 美國佬的棒子該出來了，不要老是用胡蘿蔔～',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:48'},
#   46: {'push_tag': '推',
#    'user': 'DecemberLV',
#    'comment': ' 我川=美國馬維拉',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:48'},
#   47: {'push_tag': '推',
#    'user': 'Andy5566',
#    'comment': ' 完全執政～布丁負責！',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:48'},
#   48: {'push_tag': '推',
#    'user': 'mecca',
#    'comment': ' 我無限QE是我的事情  趁我病要我命是你的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '09:53'},
#   49: {'push_tag': '噓',
#    'user': 'undft082',
#    'comment': ' 你最爛',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:03'},
#   50: {'push_tag': '推',
#    'user': 'adriano7431',
#    'comment': ' 有沒有次元刀概念股？ 看起來各國都用得不錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:04'},
#   51: {'push_tag': '推',
#    'user': 'lovefriend',
#    'comment': ' 沒看過一個美國總統被罵成這樣 拜登真是奇蹟啊!!!',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:19'},
#   52: {'push_tag': '推',
#    'user': 'NCTUEE800808',
#    'comment': ' 烏俄戰爭都打完了 還在烏俄戰爭',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:21'},
#   53: {'push_tag': '推',
#    'user': 'cblade',
#    'comment': ' 四年遺毒 失智要跟上台灣',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:21'},
#   54: {'push_tag': '推',
#    'user': 'bamama56',
#    'comment': ' 美國很多人都走了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:22'},
#   55: {'push_tag': '→',
#    'user': 'coolguychen',
#    'comment': ' 是誰讓戰爭停不下來',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:24'},
#   56: {'push_tag': '推',
#    'user': 'huabandd',
#    'comment': ' 美國都沒錯，都他們的錯，可笑',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:30'},
#   57: {'push_tag': '→',
#    'user': 'huabandd',
#    'comment': ' 推文那張圖害我笑了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:31'},
#   58: {'push_tag': '推',
#    'user': 'AGODC',
#    'comment': ' 美國蔡英文？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:42'},
#   59: {'push_tag': '噓',
#    'user': 'ARKUE',
#    'comment': ' 誰叫失智燈要幫烏克蘭 早點給俄打下來 會通膨成這',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:42'},
#   60: {'push_tag': '→',
#    'user': 'ARKUE',
#    'comment': ' 樣',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:42'},
#   61: {'push_tag': '推',
#    'user': 'saihao',
#    'comment': ' 拜EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:50'},
#   62: {'push_tag': '→',
#    'user': 'Mytsb2421',
#    'comment': ' 美國怎麼跟的上台灣菜EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:52'},
#   63: {'push_tag': '→',
#    'user': 'sachung28',
#    'comment': ' 自給自足d重要性 地球4平的信徒面臨挫敗',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:53'},
#   64: {'push_tag': '推',
#    'user': 'joeshiu',
#    'comment': ' 吃到菜EE口水？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:53'},
#   65: {'push_tag': '推',
#    'user': 'fcuk9981',
#    'comment': ' 美國假博士？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:54'},
#   66: {'push_tag': '噓',
#    'user': 'im2a27',
#    'comment': ' 跟台灣 廢物ee好像',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:54'},
#   67: {'push_tag': '→',
#    'user': 'WEYNI',
#    'comment': ' 好..我們正名 失智老人通膨',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:56'},
#   68: {'push_tag': '推',
#    'user': 'swaggyyang',
#    'comment': ' 什麼米國蔡 失智症爛多了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:57'},
#   69: {'push_tag': '推',
#    'user': 'ixeasawm',
#    'comment': ' 拜登真的爛 還我川普',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:58'},
#   70: {'push_tag': '推',
#    'user': 'neoa01',
#    'comment': ' 奇怪 你制裁別人的不是嗎？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '10:59'},
#   71: {'push_tag': '推',
#    'user': 'NEX4036',
#    'comment': ' Jobs from USA.',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:00'},
#   72: {'push_tag': '推',
#    'user': 'silvertiger',
#    'comment': ' 咦!!俄羅斯不是折價賣油給中國、印度嗎?哪有漲價?',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:01'},
#   73: {'push_tag': '推',
#    'user': 'ab4daa',
#    'comment': ' 可憐哪',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:03'},
#   74: {'push_tag': '→',
#    'user': 'NEX4036',
#    'comment': ' https://i.imgur.com/vgLXqWu.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:04'},
#   75: {'push_tag': '推',
#    'user': 'nckuman',
#    'comment': ' 美國其邁',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:05'},
#   76: {'push_tag': '推',
#    'user': 'chein17',
#    'comment': ' 左膠的U值選擇',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:08'},
#   77: {'push_tag': '噓',
#    'user': 'Tab',
#    'comment': ' 美國空心菜',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:11'},
#   78: {'push_tag': '→',
#    'user': 'rexlin',
#    'comment': ' 自己搞無限QE是幫兇之一還好意思講別人',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:12'},
#   79: {'push_tag': '推',
#    'user': 'r85270607',
#    'comment': ' 中時寫這個我是不意外 真讓我意外的是自由也寫這個',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:18'},
#   80: {'push_tag': '推',
#    'user': 'eelse',
#    'comment': ' 失智登，你看川普當總統的話俄國敢不敢打',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:21'},
#   81: {'push_tag': '噓',
#    'user': 'komoa',
#    'comment': ' 竭盡所能降低，所以說你拜登到底做了什麼？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:29'},
#   82: {'push_tag': '→',
#    'user': 'herculus6502',
#    'comment': ' 塊 陶 啊',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:36'},
#   83: {'push_tag': '推',
#    'user': 'Arizona989',
#    'comment': ' 老拜手都指別人呀，這真不行',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:37'},
#   84: {'push_tag': '推',
#    'user': 'este1a',
#    'comment': ' 蔡英文效應',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:40'},
#   85: {'push_tag': '推',
#    'user': 'popxx123',
#    'comment': ' 可憐',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:41'},
#   86: {'push_tag': '→',
#    'user': 'popxx123',
#    'comment': ' 沒料就是推',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:41'},
#   87: {'push_tag': '推',
#    'user': 'fablife',
#    'comment': ' 拜登政府真的太廢了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:41'},
#   88: {'push_tag': '噓',
#    'user': 'siibouf',
#    'comment': ' 錯都別人 跟某人好像',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:48'},
#   89: {'push_tag': '推',
#    'user': 'kevin540',
#    'comment': ' 加入北約：',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:48'},
#   90: {'push_tag': '推',
#    'user': 'betrayalme',
#    'comment': ' 美國馬英九吧',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:52'},
#   91: {'push_tag': '→',
#    'user': 'aoc902001',
#    'comment': ' 怎麼不繼續油頁岩產油？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:52'},
#   92: {'push_tag': '推',
#    'user': 'stosto',
#    'comment': ' 川普大概搞QE時已經想到拜登上去後他接著要怎麼選了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:55'},
#   93: {'push_tag': '→',
#    'user': 'stosto',
#    'comment': ' 拜登連上去後怎麼做都沒想',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '11:55'},
#   94: {'push_tag': '推',
#    'user': 'preferalie',
#    'comment': ' 都是they的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:04'},
#   95: {'push_tag': '→',
#    'user': 'tabrisPTT',
#    'comment': ' 拜登的博班論文呢？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:06'},
#   96: {'push_tag': '推',
#    'user': 'DEAKUNE',
#    'comment': ' 戰爭前的通膨=預通膨、類通膨，反正怎樣都能扯到普',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:10'},
#   97: {'push_tag': '→',
#    'user': 'DEAKUNE',
#    'comment': ' 丁',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:10'},
#   98: {'push_tag': '推',
#    'user': 'gowang19',
#    'comment': ' 世界怎麼跟的上台灣 哈哈',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:10'},
#   99: {'push_tag': '推',
#    'user': 'realmd',
#    'comment': ' 想挺烏拖死俄?? 結果自已先倒  笑死',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:14'},
#   100: {'push_tag': '→',
#    'user': 'kilhi',
#    'comment': ' 美國蔡EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:15'},
#   101: {'push_tag': '→',
#    'user': 'kilhi',
#    'comment': ' 這只是剛開始',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:15'},
#   102: {'push_tag': '→',
#    'user': 'realmd',
#    'comment': ' 然後俄嘗到甜頭也開始慢慢打，大家一起拖台錢',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:16'},
#   103: {'push_tag': '推',
#    'user': 'pipi2',
#    'comment': ' りしれ供三小',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:18'},
#   104: {'push_tag': '推',
#    'user': 'tetani',
#    'comment': ' 整個爆發點就是司機想加入北約',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:20'},
#   105: {'push_tag': '→',
#    'user': 'tetani',
#    'comment': ' 當初美國出面反對烏克蘭加入北約 就沒什麼事了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:21'},
#   106: {'push_tag': '→',
#    'user': 'tetani',
#    'comment': ' 看美國援助烏克蘭的錢 要怎麼回收',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:22'},
#   107: {'push_tag': '推',
#    'user': 'qk31330',
#    'comment': ' 樓下支援小丑圖',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:22'},
#   108: {'push_tag': '→',
#    'user': 'z256418',
#    'comment': ' 要不要學一下中國封城打需求，通通回去wfh不要出門',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:23'},
#   109: {'push_tag': '→',
#    'user': 'z256418',
#    'comment': ' 減少加油需求=.=',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:23'},
#   110: {'push_tag': '噓',
#    'user': 'leepohom',
#    'comment': ' 台灣政客領先全球',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:28'},
#   111: {'push_tag': '推',
#    'user': 'dbdudsorj',
#    'comment': ' 史上最廢美國總統 認證',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:28'},
#   112: {'push_tag': '推',
#    'user': 'wumo',
#    'comment': ' 普維拉',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:29'},
#   113: {'push_tag': '推',
#    'user': 'a91031309',
#    'comment': ' 笑死，跟台灣垃圾有得比',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:55'},
#   114: {'push_tag': '推',
#    'user': 'jamespon1',
#    'comment': ' 好熟悉的套路',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:55'},
#   115: {'push_tag': '→',
#    'user': 'nata12',
#    'comment': ' 美國國民黨 專門靠賤招拿外來移民非法移民票',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:55'},
#   116: {'push_tag': '→',
#    'user': 'CGDGAD',
#    'comment': ' 不只是台灣連美國人都投錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '12:57'},
#   117: {'push_tag': '噓',
#    'user': 'neweb',
#    'comment': ' 明明就是米國搞俄國經經濟，結果傷到自己還怪別人',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:01'},
#   118: {'push_tag': '→',
#    'user': 'nwoyao',
#    'comment': ' 糧食太貴了啦 拜登快去查看看',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:06'},
#   119: {'push_tag': '→',
#    'user': 'nwoyao',
#    'comment': ' 川普：哈哈 當初錢發的好爽',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:07'},
#   120: {'push_tag': '推',
#    'user': 'sova0809',
#    'comment': ' 歐美自己搞出來的爛攤子 自己看著辦 原物料供應已',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:20'},
#   121: {'push_tag': '→',
#    'user': 'sova0809',
#    'comment': ' 經被搞得面目全非了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:20'},
#   122: {'push_tag': '→',
#    'user': 'sova0809',
#    'comment': ' 想通膨想瘋了 有本事就印出原物料看看唄',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:21'},
#   123: {'push_tag': '→',
#    'user': 'sova0809',
#    'comment': ' 89月要是小麥收成開出來歉收 那下一波高潮會非常非',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:24'},
#   124: {'push_tag': '→',
#    'user': 'sova0809',
#    'comment': ' 常難看 再冬季天然氣問題前我比較擔心這個',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:24'},
#   125: {'push_tag': '推',
#    'user': 'ZakuSIN',
#    'comment': ' 美國車輪黨  跟舔共仔一模一樣',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:37'},
#   126: {'push_tag': '推',
#    'user': 'EddieWuRJJ',
#    'comment': ' 烏俄戰爭石油供給面問題不解決 單純靠升息貨幣政策',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:42'},
#   127: {'push_tag': '→',
#    'user': 'EddieWuRJJ',
#    'comment': ' 很難壓CPI',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:42'},
#   128: {'push_tag': '→',
#    'user': 'ffbbhh',
#    'comment': ' 完全美國馬英9',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:50'},
#   129: {'push_tag': '推',
#    'user': 'ByronX',
#    'comment': ' 反被制衡裝被害者',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '13:55'},
#   130: {'push_tag': '→',
#    'user': 'onit',
#    'comment': ' 這老頭跟馬英九相似度也太高了 各種政確 物價 油電',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:00'},
#   131: {'push_tag': '→',
#    'user': 'onit',
#    'comment': ' 雙掌 然後搞死自己',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:00'},
#   132: {'push_tag': '推',
#    'user': 'BIGETC',
#    'comment': ' 這也抄台灣 地表最強國就這樣?',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:05'},
#   133: {'push_tag': '→',
#    'user': 's155260',
#    'comment': ' 智障老人',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:06'},
#   134: {'push_tag': '→',
#    'user': 'x6urvery',
#    'comment': ' 美國EE 萬物其漲 厲害',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:08'},
#   135: {'push_tag': '→',
#    'user': 'onit',
#    'comment': ' 當年馬英九因為中油 台電一直喊虧損 結果直接放手',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:09'},
#   136: {'push_tag': '→',
#    'user': 'onit',
#    'comment': ' 油電雙掌害死自己 導致到現在沒有人敢漲',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:09'},
#   137: {'push_tag': '推',
#    'user': 'okbon',
#    'comment': ' 老實說就是拜先生上來後 通膨開始肆無忌憚',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:44'},
#   138: {'push_tag': '→',
#    'user': 'okbon',
#    'comment': ' 搞綠能 政府效率又低  放任房市大漲',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:45'},
#   139: {'push_tag': '推',
#    'user': 'stilu',
#    'comment': ' 拜登也懂前朝遺毒？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:51'},
#   140: {'push_tag': '推',
#    'user': 'david3033',
#    'comment': ' https://i.imgur.com/kZwNEtt.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '14:52'},
#   141: {'push_tag': '噓',
#    'user': 'chaoliu',
#    'comment': ' I told you ==',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '15:01'},
#   142: {'push_tag': '噓',
#    'user': 'oklaptt',
#    'comment': ' 美國人狂印錢輸出通膨都沒錯？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '15:12'},
#   143: {'push_tag': '噓',
#    'user': 'sailaphair1',
#    'comment': ' 都是they的錯~',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '15:56'},
#   144: {'push_tag': '推',
#    'user': 'otaku5566',
#    'comment': ' 美國人民不吃這套嗎，我看台灣人都相信耶',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '16:30'},
#   145: {'push_tag': '推',
#    'user': 'ultraccs',
#    'comment': ' 還不是拜登自己搞的 美國滿手油頁岩不挖',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '16:40'},
#   146: {'push_tag': '→',
#    'user': 'provider17',
#    'comment': ' 都是they 的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '16:59'},
#   147: {'push_tag': '推',
#    'user': 'nutrino',
#    'comment': ' 笑死惹 美國蔡統',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:06'},
#   148: {'push_tag': '推',
#    'user': 'w300204',
#    'comment': ' 都是They的錯',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:24'},
#   149: {'push_tag': '推',
#    'user': 'cherokee2006',
#    'comment': ' 美國馬英九，超廢',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:30'},
#   150: {'push_tag': '推',
#    'user': 'billionaire',
#    'comment': ' https://i.imgur.com/HmTcSAK.jpg',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:34'},
#   151: {'push_tag': '推',
#    'user': 'justeat',
#    'comment': ' 笑死',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:37'},
#   152: {'push_tag': '推',
#    'user': 'Crazyfire',
#    'comment': ' 普維拉 沒戰爭就改怪川普了',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '17:42'},
#   153: {'push_tag': '→',
#    'user': 'Rickyyy',
#    'comment': ' 左膠就是滿嘴仁義道德，做事亂七八糟',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '18:49'},
#   154: {'push_tag': '推',
#    'user': 'JANYUJEN',
#    'comment': ' 普丁又沒說不賣你，自己不買怪人家？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '19:07'},
#   155: {'push_tag': '推',
#    'user': 'jrbobo',
#    'comment': ' 美國EE',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '21:34'},
#   156: {'push_tag': '推',
#    'user': 'doubleperson',
#    'comment': ' 拜登484請EE當顧問？',
#    'ip': None,
#    'comment_date': '06/12',
#    'comment_time': '23:43'}}}

# %%
df = pd.DataFrame(data['comment']).T
df
# Out:
#     push_tag          user             comment    ip comment_date comment_time
# 0          推      y1896547     抗俄保美 美國價值 新美國模式  None        06/12        07:55
# 1          推    KyleSeager        那烏俄戰爭前的通膨是？？  None        06/12        07:57
# 2          →  AustinRivers                =.=a  None        06/12        07:57
# 3          噓        a38654       美國蔡英文 都是阿共的錯！  None        06/12        07:59
# 4          推           cpz             美國jobs讚  None        06/12        08:02
# ..       ...           ...                 ...   ...          ...          ...
# 152        推     Crazyfire       普維拉 沒戰爭就改怪川普了  None        06/12        17:42
# 153        →       Rickyyy   左膠就是滿嘴仁義道德，做事亂七八糟  None        06/12        18:49
# 154        推      JANYUJEN   普丁又沒說不賣你，自己不買怪人家？  None        06/12        19:07
# 155        推        jrbobo                美國EE  None        06/12        21:34
# 156        推  doubleperson        拜登484請EE當顧問？  None        06/12        23:43
#
# [157 rows x 6 columns]
